# %% [markdown]
# # Tutorial for Downloading Data from the ArcGIS API for Python

# %%
# getting necessary imports
from arcgis.gis import GIS
from pathlib import Path
from zipfile import ZipFile

gis = GIS()

# %% [markdown]
# There was aan error that occured with a suggestion that urlib3 newre verison was the reason wha it didn't work, checking to see if adjusting it per [this website](https://learn.microsoft.com/en-us/answers/questions/1276637/arcgis-package-urllib3-library-issue) will work.
#
# The soultion worked, the requirements/txt will remain as it is

# %% [markdown]
# ### 3. The content property for gis is an instance of a ContentManager that is used to manage content on ArcGIS Online. get() makes an ArcGIS REST API request to retrieve an Item object.

# %%
gis = GIS()

public_data_item_id = 'a04933c045714492bda6886f355416f2'

# check to see if the id exist
data_item = gis.content.get(public_data_item_id)
data_item
# Out:
# <Item title:"ArcGIS Tutorial Datasets" type:Code Sample owner:esri_devlabs>

# %% [markdown]
# ### 4. Download LA_Hub_datasets.zip to the notebook server's current location.

# %%
# configure where to save the data and where the ZIP file is located
data_path = Path('./data')
if not data_path.exists():
    data_path.mkdir()

zip_path = data_path.joinpath('LA_Hub_Datasets.zip')
print(zip_path)

extract_path = data_path.joinpath('la_hub_datasets')
print(extract_path)

# data_item.download(save_path=data_path)
# Out:
# data/LA_Hub_Datasets.zip
# data/la_hub_datasets

# %% [markdown]
# ### 5. Use ZipFile to extract the contents of the dataset.

# %%
zip_file = ZipFile(zip_path)
print(zip_file)
zip_file.extractall(path=data_path)
# Out:
# <zipfile.ZipFile filename='data/LA_Hub_Datasets.zip' mode='r'>

# %% [markdown]
# ### 6. Call glob('*') on the extract_path to list the contents of the data directory.

# %%
files = [file.name for file in extract_path.glob('*')]
files
# Out:
# ['Parks_and_Open_Space.zip', 'Trails.geojson', 'Trailheads.csv']

# %%
import pandas as pd
pd.read_csv('./data/LA_Hub_Datasets/Trailheads.csv')
# Out:
# /var/folders/fj/7fbysvvn7956npcj9d4mxfxw0000gn/T/ipykernel_2129/2324004553.py:2: DtypeWarning: Columns (0,4,7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv('./data/LA_Hub_Datasets/Trailheads.csv')
#       OBJECTID                 TRL_NAME                      PARK_NAME  \
# 0         7769        Medea Creek Trail         National Parks Service
# 1         8047     Hearst Tank Motorway         National Parks Service
# 2         7770     Medicine Woman Trail         National Parks Service
# 3         8048   Pipe Corral Spur Trail       CA State Parks - Topanga
# 4         7773       Mesa Peak Motorway  CA State Parks - Malibu Creek
# ...        ...                      ...                            ...
# 32860     8041      Joesepho Spur Trail       CA State Parks - Topanga
# 32861     8042  Murphy Ranch Road Trail       CA State Parks - Topanga
# 32862     8043    Piuma Connector Trail
# 32863     8044              Puerco Mtwy  CA State Parks - Malibu Creek
# 32864     8046      Musch Meadows Trail       CA State Parks - Topanga
#
#         TRL_ID       SEG_ID FEATURE                    FEAT_CMNT ELEV_FT  \
# 0      20082.0  200820000.0    TAPO  Auto Generated and Verified   831.0
# 1      20067.0  200670000.0    TAPO                          NaN  1555.0
# 2      20084.0  200840000.0      TH  Auto Generated and Verified   758.0
# 3      10133.0  101330000.0    TAPO  Auto Generated and Verified     0.0
# 4      10112.0  101120000.0      TH  Auto Generated and Verified  1982.0
# ...        ...          ...     ...                          ...     ...
# 32860  10088.0    300070000    TAPO  Auto Generated and Verified     415
# 32861  20138.0    300070000    TAPO  Auto Generated and Verified     415
# 32862  10135.0    100180000    TAPO                          NaN     485
# 32863  10140.0    101120000    TAPO  Auto Generated and Verified     748
# 32864  10117.0    101170000    TAPO  Auto Generated and Verified    1137
#
#                                 CITY_JUR ZIP_CODE      SUP_DIST  \
# 0      Unincorporated Los Angeles County  91301.0  3rd District
# 1      Unincorporated Los Angeles County  90290.0  3rd District
# 2      Unincorporated Los Angeles County  91301.0  3rd District
# 3                            Los Angeles  90272.0  3rd District
# 4      Unincorporated Los Angeles County  90265.0  3rd District
# ...                                  ...      ...           ...
# 32860                        Los Angeles    90272  3rd District
# 32861                        Los Angeles    90272  3rd District
# 32862  Unincorporated Los Angeles County    91302  3rd District
# 32863  Unincorporated Los Angeles County    91302  3rd District
# 32864  Unincorporated Los Angeles County    90290  3rd District
#
#                                          X_STREET PARKING  PHOTO        LAT  \
# 0                             28825 Lake Vista Dr      SA    NaN  34.113057
# 1                             3200 Tuna Canyon Rd      ST    NaN  34.059687
# 2                                 2900 Cornell Rd      SA    NaN  34.117364
# 3                                             NaN      ST    NaN  34.079346
# 4                            300 Corral Canyon Rd      ST    NaN  34.079060
# ...                                           ...     ...    ...        ...
# 32860              1666 Will Rogers State Park Rd      SA    NaN  34.054416
# 32861              1666 Will Rogers State Park Rd      SA    NaN  34.054416
# 32862                         897 Las Virgenes Rd      SA    NaN  34.083164
# 32863                              Mesa Peak Mtwy      ST    NaN  34.078255
# 32864  Topanga Canyon Boulevard and Oakwood Drive      SA    NaN  34.110721
#
#               LON    FID           x          y
# 0     -118.751527    1.0 -118.751527  34.113057
# 1     -118.616545    2.0 -118.616545  34.059687
# 2     -118.756839    3.0 -118.756839  34.117364
# 3     -118.519724    4.0 -118.519724  34.079346
# 4     -118.755563    5.0 -118.755563  34.079060
# ...           ...    ...         ...        ...
# 32860 -118.509626  316.0 -118.509626  34.054416
# 32861 -118.509626  317.0 -118.509626  34.054416
# 32862 -118.705501  318.0 -118.705501  34.083164
# 32863 -118.710416  319.0 -118.710416  34.078255
# 32864 -118.588759  320.0 -118.588759  34.110721
#
# [32865 rows x 19 columns]
